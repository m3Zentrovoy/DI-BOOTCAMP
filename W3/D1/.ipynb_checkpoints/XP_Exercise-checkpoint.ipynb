# %%
import pandas as pd


df1 = pd.read_csv('How Much Sleep Do Americans/Time Americans Spend Sleeping.csv')
df2 = pd.read_csv('Global Trends in Mental Health Disorder/Mental health Depression disorder Data.csv')
df3 = pd.read_csv('Credit Card Approvals (Clean Data)/clean_dataset.csv')
df4 = pd.read_csv('Credit Card Approvals (Clean Data)/crx.csv')

print("df1 columns:", df1.columns)
print(df1.head())
print("\nColumns:", df1.columns)

# print("df2 columns:", df2.columns)
# print(df2.head())
# print("df3 columns:", df3.columns)
# print(df3.head())
# print("df4 columns:", df4.columns)
# print(df4.head())

#ex3

# qualitative_columns = df1.select_dtypes(include=['object']).columns
# print("Qualitative columns in df1:", qualitative_columns)
# quantitative_columns = df1.select_dtypes(include=['float64', 'int64']).columns
# print("Quantitative columns in df1:", quantitative_columns)

# qualitative_columns = df2.select_dtypes(include=['object']).columns
# print("Qualitative columns in df2:", qualitative_columns)
# quantitative_columns = df2.select_dtypes(include=['float64', 'int64']).columns
# print("Quantitative columns in df2:", quantitative_columns)


# qualitative_columns = df3.select_dtypes(include=['object']).columns
# print("Qualitative columns in df3:", qualitative_columns)
# quantitative_columns = df3.select_dtypes(include=['float64', 'int64']).columns
# print("Quantitative columns in df3:", quantitative_columns)

# qualitative_columns = df4.select_dtypes(include=['object']).columns
# print("Qualitative columns in df4:", qualitative_columns)
# quantitative_columns = df4.select_dtypes(include=['float64', 'int64']).columns
# print("Quantitative columns in df4:", quantitative_columns)


# iris = pd.read_csv('Iris.csv')
# print(iris.head())

# qualitative_columns = iris.select_dtypes(include=['object']).columns
# print("Qualitative (Non-numerical data ) columns in iris:", qualitative_columns)
# quantitative_columns = iris.select_dtypes(include=['float64', 'int64']).columns
# print("Quantitative (Numerical data) columns in iris:", quantitative_columns)

# for column in quantitative_columns:
#     mean = iris[column].mean()
#     median = iris[column].median()
#     mode = iris[column].mode()[0]  # mode() возвращает Series, берём первое значение
#     print(f"\nStatistics for '{column}':")
#     print(f"Mean: {mean}")
#     print(f"Median: {median}")
#     print(f"Mode: {mode}")


import matplotlib.pyplot as plt
# plt.plot(iris['SepalLengthCm'])
# plt.show()

#ex6
trend_data = df1[(df1['Type of Days'] == 'All days') & (df1['Sex'] == 'Both') & (df1['Age Group'] == '15 years and over')]
plt.plot(trend_data['Year'], trend_data['Avg hrs per day sleeping'])
plt.xlabel('Year')
plt.ylabel('Average Hours of Sleep per Day')
plt.title('Trend of Sleep Duration (2003-2017)')
plt.show()

# Средние значения для каждого пола
group_means = df1.groupby('Sex')['Avg hrs per day sleeping'].mean()
print(group_means)


"""### Columns for Specific Types of Analysis in Time Americans Spend Sleeping.csv

#### Trend Analysis
- **Year** and **Avg hrs per day sleeping**: `Year` (2003–2017) allows tracking changes over time, and `Avg hrs per day sleeping` shows the average sleep duration. This can reveal trends, such as whether sleep duration increases or decreases over the years.
  - Example: Analyze the trend of sleep duration for "All days" and "Both" sexes from 2003 to 2017.

#### Group Comparison
- **Type of Days**, **Age Group**, **Sex** (grouping columns) and **Avg hrs per day sleeping** (value column): These columns allow comparing sleep duration across different groups.
  - Example 1: Compare sleep duration on "Nonholiday weekdays" vs. "Weekend days and holidays".
  - Example 2: Compare sleep duration for "15 to 24 years" vs. "65 years and over".
  - Example 3: Compare sleep duration for "Men" vs. "Women".

#### Error Analysis
- **Avg hrs per day sleeping** and **Standard Error**: `Standard Error` provides the margin of error for `Avg hrs per day sleeping`, allowing analysis of measurement reliability.
  - Example: Plot sleep duration with error bars to visualize the uncertainty in the data."""
# Out:
# df1 columns: Index(['index', 'Year', 'Period', 'Avg hrs per day sleeping', 'Standard Error',
#        'Type of Days', 'Age Group', 'Activity', 'Sex'],
#       dtype='object')
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both
#
# Columns: Index(['index', 'Year', 'Period', 'Avg hrs per day sleeping', 'Standard Error',
# ...

# %% [markdown]
# 🌟Exercise 5: Basic Data Analysis with Google Colab
# "Document your findings in the notebook."
#
# ### Visualization Findings for Iris Dataset
#
# #### Histogram of SepalLengthCm
# - The histogram shows the distribution of sepal lengths across all iris flowers.
# - Most sepal lengths are between 4.5 and 7.0 cm, with peaks around 5.0 cm and 6.0 cm.
# - This indicates that the majority of iris flowers have sepal lengths in this range, with fewer flowers having very small (around 4.3 cm) or very large (around 7.9 cm) sepal lengths.
#
# #### Bar Chart of Average Sepal Length by Species
# - The bar chart compares the average sepal length for each iris species.
# - **Iris-setosa** has the smallest average sepal length (around 5.0 cm), indicating smaller flowers.
# - **Iris-versicolor** has a medium average sepal length (around 5.9 cm).
# - **Iris-virginica** has the largest average sepal length (around 6.6 cm), suggesting larger flowers.
# - This suggests that sepal length can be a distinguishing feature between species, with setosa being the smallest and virginica the largest.
