# %%
# Основные темы
# Зачем нужно предобработка данных:
# Предобработка исправляет ошибки, пропуски и несоответствия в данных, чтобы обеспечить качественный анализ и точные модели.
# Сбор и изучение данных:
# Сбор данных: Загрузка датасета (например, Titanic с Kaggle через API).
# Изучение данных: Использование df.head() и df.info() для анализа структуры, типов данных и пропусков.
# Интеграция данных:
# Объединение данных из разных источников (например, pd.merge() по ключу PassengerId с типом слияния how='left').
# Очистка данных:
# Удаление дубликатов: df.drop_duplicates().
# Удаление ненужных данных: Удаление столбцов (df.drop(['Cabin', 'Ticket'], axis=1)).
# Исправление структурных ошибок: Например, преобразование формата даты (pd.to_datetime()).
# Обработка пропусков:
# Поиск: df.isnull().sum().
# Удаление: df.dropna() (подходит, если пропусков мало).
# Заполнение: df.fillna(0) или df.fillna(df.mean()).
# Продвинутое заполнение: KNNImputer из sklearn.
# Обработка выбросов:
# Использование IQR для столбца Fare: Q1, Q3, IQR, границы (lower_bound, upper_bound), фильтрация данных.
# Ключевые выводы
# Предобработка данных критически важна для точного анализа и моделирования.
# Интеграция и очистка данных помогают объединить информацию и устранить ошибки.
# Пропуски и выбросы нужно обрабатывать с учётом задачи (удаление, заполнение, фильтрация).
# Ответы на Knowledge Check
# Почему важна предобработка? C) Для обеспечения качественных данных.
# Зачем изучать данные? C) Для понимания структуры и пропусков.
# Ключ для слияния? D) PassengerId.
# Параметр how в pd.merge()? B) Указывает тип слияния.
# Когда удалять пропуски? C) Если они в определённых столбцах.
# Когда заполнять 0? Когда 0 имеет смысл (например, отсутствие значения).
